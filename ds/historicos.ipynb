# %%
import pandas as pd
df_historico_2022 = pd.read_excel("../data/BASE DE DATOS HISTORICO 2022.xlsx",engine='openpyxl')
# Out:
# a:\Python37\lib\site-packages\openpyxl\worksheet\_reader.py:211: UserWarning: Cell F874 is marked as a date but the serial value 35456871 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)

# %%
df_historico_2022.shape
# Out:
# (7083, 527)

# %%
df_historico_2022.head()
# Out:
#       N° MOTIVO DE LA VISITA N°. ACTA VISITA N°. ACTA CONTROL  \
# 0  ET001                 NaN             NaN              NaN
# 1    NaN                 NaN             NaN              NaN
# 2    NaN                 NaN             NaN              NaN
# 3    NaN                 NaN             NaN              NaN
# 4    NaN                 NaN             NaN              NaN
#
#        FECHA DE VISITA     FECHA DE INGRESO                RAZON SOCIAL   \
# 0  2016-02-07 00:00:00  2017-02-15 00:00:00                            |
# 1  2018-04-02 00:00:00  2018-04-09 00:00:00     TIENDA LA MONITA DE LA 1
# 2  2018-06-19 00:00:00  2018-06-25 00:00:00     TIENDA LA MONITA DE LA 1
# 3  2020-05-12 00:00:00  2020-06-01 00:00:00     TIENDA LA MONITA DE LA 1
# 4  2021-12-02 00:00:00                 None  ORDUZ FIGUEREDO AURA ALICIA
#
#   *CEDULA - NIT.              * NOMBRE COMERCIAL * NUMERO DE INSCRIPCION  ...  \
# ...
