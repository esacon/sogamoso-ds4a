# %%
import pandas as pd
df_alimentos_autoservicios = pd.read_csv('../data/data_alimentos/alimentos-autoservicios.csv', sep=';')
df_alimentos_comedores_geriatricos = pd.read_csv('../data/data_alimentos/alimentos-comedores-geriatricos.csv', sep=';')
# Out:
# (17, 33)

# %%
df_alimentos_autoservicios.shape
# Out:
# (129, 35)

# %%
df_alimentos_comedores_geriatricos.shape
# Out:
# (17, 33)
